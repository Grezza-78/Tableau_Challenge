# %%
# Dependencies and Setup
import pandas as pd

# %%
# CitiBike data files to be combined
files_2022_2023 = ["CSV/JC-202206.csv","CSV/JC-202207.csv","CSV/JC-202208.csv","CSV/JC-202209.csv","CSV/JC-202210.csv","CSV/JC-202211.csv","CSV/JC-202212.csv","CSV/JC-202301.csv","CSV/JC-202302.csv","CSV/JC-202303.csv","CSV/JC-202304.csv","CSV/JC-202305.csv"]

# Create an empty list to store each dataframe
df_list = []

# Loop through each file in the list
for file in files_2022_2023:

    # Read the file into a dataframe
    df_22_23_years = pd.read_csv(file)

    # Append the dataframe to the list
    df_list.append(df_22_23_years)

# Concatenate all dataframes in the list into one dataframe
df_22_23_years = pd.concat(df_list)

# Show dataframe
df_22_23_years
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1      BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2      DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3      A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4      A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                 ...            ...                  ...
# 95997  9549398286BB59B5    docked_bike  2023-05-27 13:24:51
# 95998  AB0790683044D89E   classic_bike  2023-05-18 17:12:07
# 95999  68226FA538A405CA   classic_bike  2023-05-05 18:44:57
# 96000  CABAC21C0F0140A5   classic_bike  2023-05-16 11:56:11
# 96001  4AABD797EF6F7BB2   classic_bike  2023-05-30 11:04:46
#
#                   ended_at                            start_station_name  \
# 0      2022-06-30 19:27:13                        Clinton St & Newark St
# 1      2022-06-02 15:08:33                        Clinton St & Newark St
# ...

# %%
# Save the dataframe to a CSV file
df_22_23_years.to_csv('./Data/citibike.csv', index=False)
